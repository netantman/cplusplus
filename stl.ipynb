# %% [markdown]
# ### What is the full name of STL?
#
# Standard template library. It is a library of container templates that provide generic classes and functions.
#
# STL components are containers, algorithms, iterators, and function objects.
#
# ![image.png](attachment:image.png)
